# %% [markdown]
# <a href="https://colab.research.google.com/github/FasikuChristian/QSAR-Modeling-Pipeline-for-Serine-Threonine-Kinase-1/blob/main/CDD_ML_Part_1_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data using *CHEMBL DATABASE*
#
# Credits: Chanin Nantasenamat(Data Professor) for developing this pipeline
#
# ---

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for AKT1**

# %%
# Target search for AKT1
target = new_client.target
target_query = target.search('AKT Serine/Threonine Kinase 1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#      cross_references                                         organism  \
# 0                  []                                     Homo sapiens
# 1                  []                                     Mus musculus
# 2                  []                                     Mus musculus
# 3                  []                                     Homo sapiens
# 4                  []                                     Homo sapiens
# ...               ...                                              ...
# 5870               []  Severe acute respiratory syndrome coronavirus 2
# 5871               []                                     Homo sapiens
# 5872               []                                     Mus musculus
# 5873               []  Severe acute respiratory syndrome coronavirus 2
# 5874               []  Severe acute respiratory syndrome coronavirus 2
#
#                                               pref_name  score  \
# ...

# %%
targets.head()
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Mus musculus
# 2               []  Mus musculus
# 3               []  Homo sapiens
# 4               []  Homo sapiens
#
#                                         pref_name  score  species_group_flag  \
# 0             Serine/threonine-protein kinase AKT   29.0               False
# 1        RAC-beta serine/threonine-protein kinase   28.0               False
# 2       RAC-alpha serine/threonine-protein kinase   28.0               False
# 3  Serine/threonine-protein kinase Rac alpha/beta   28.0               False
# 4        RAC-beta serine/threonine-protein kinase   27.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL2111353  [{'accession': 'P31751', 'component_descriptio...
# 1       CHEMBL5382  [{'accession': 'Q60823', 'component_descriptio...
# 2       CHEMBL5859  [{'accession': 'P31750', 'component_descriptio...
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *AKT1* (fifth entry)**

# %% [markdown]
# We will assign the first entry (which corresponds to the target protein, *AKT1*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2111353'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *AKT1* (CHEMBL2111353) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       316960                  []
# 1        None             None       328362                  []
# 2        None             None       491918                  []
#
#   assay_chembl_id                                assay_description assay_type  \
# 0    CHEMBL766864  Inhibition of Protein kinase B (AKT) at ATP <Km          B
# 1    CHEMBL766865  Inhibition of Protein kinase B (AKT) at ATP <Km          B
# 2    CHEMBL709030  Inhibition of Akt phosphorylation in LoVo cells          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
#   target_organism                     target_pref_name target_tax_id  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# -rw------- 1 root root 122535 Mar 20 07:20 '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 151  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 152  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 153  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 154  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 155  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL281872         COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCn1ccnn1
# 1         CHEMBL533849   COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1.Cl
# 2         CHEMBL414139  COc1cc2c(Nc3ccc(Oc4ccccc4)cc3)c(C#N)cnc2cc1OCC...
# 3         CHEMBL318804  COc1cc2c(Nc3ccc(Sc4nccn4C)c(Cl)c3)c(C#N)cnc2cc...
# 4        CHEMBL2368948  CCCCCCCCCCCCCCCCCCOC[C@H](COP(=O)(O)O[C@H]1[C@...
# ..                 ...                                                ...
# 150       CHEMBL595583            CCCCCCCCCCCCc1ccc(S(=O)(=O)Nc2nncs2)cc1
# 151      CHEMBL1186409  CC[n+]1c(/C=C/N(C)c2ccccc2)n(-c2ccccc2)c2ccc(-...
# 152       CHEMBL379218  Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4ccccc4)c3)...
# 153       CHEMBL494089  CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 154       CHEMBL595583            CCCCCCCCCCCCc1ccc(S(=O)(=O)Nc2nncs2)cc1
#
#     bioactivity_class standard_value
# 0            inactive        20000.0
# ...

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL281872         COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCn1ccnn1
# 1         CHEMBL533849   COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1.Cl
# 2         CHEMBL414139  COc1cc2c(Nc3ccc(Oc4ccccc4)cc3)c(C#N)cnc2cc1OCC...
# 3         CHEMBL318804  COc1cc2c(Nc3ccc(Sc4nccn4C)c(Cl)c3)c(C#N)cnc2cc...
# 4        CHEMBL2368948  CCCCCCCCCCCCCCCCCCOC[C@H](COP(=O)(O)O[C@H]1[C@...
# ..                 ...                                                ...
# 151       CHEMBL595583            CCCCCCCCCCCCc1ccc(S(=O)(=O)Nc2nncs2)cc1
# 152      CHEMBL1186409  CC[n+]1c(/C=C/N(C)c2ccccc2)n(-c2ccccc2)c2ccc(-...
# 153       CHEMBL379218  Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4ccccc4)c3)...
# 154       CHEMBL494089  CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 155       CHEMBL595583            CCCCCCCCCCCCc1ccc(S(=O)(=O)Nc2nncs2)cc1
#
#     standard_value
# 0          20000.0
# 1          20000.0
# ...

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL281872         COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCn1ccnn1
# 1         CHEMBL533849   COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1.Cl
# 2         CHEMBL414139  COc1cc2c(Nc3ccc(Oc4ccccc4)cc3)c(C#N)cnc2cc1OCC...
# 3         CHEMBL318804  COc1cc2c(Nc3ccc(Sc4nccn4C)c(Cl)c3)c(C#N)cnc2cc...
# 4        CHEMBL2368948  CCCCCCCCCCCCCCCCCCOC[C@H](COP(=O)(O)O[C@H]1[C@...
# ..                 ...                                                ...
# 152      CHEMBL1186409  CC[n+]1c(/C=C/N(C)c2ccccc2)n(-c2ccccc2)c2ccc(-...
# 153       CHEMBL379218  Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4ccccc4)c3)...
# 154       CHEMBL494089  CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 155       CHEMBL595583            CCCCCCCCCCCCc1ccc(S(=O)(=O)Nc2nncs2)cc1
# 29                 NaN                                                NaN
#
#     standard_value             0
# 0          20000.0      inactive
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 144
# -rw-r--r-- 1 root root 122535 Mar 20 07:17 bioactivity_data.csv
# -rw-r--r-- 1 root root  13019 Mar 20 07:22 bioactivity_preprocessed_data.csv
# drwx------ 5 root root   4096 Mar 20 07:18 gdrive
# drwxr-xr-x 1 root root   4096 Mar 17 17:58 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
import os

dest_dir = "/content/gdrive/MyDrive/Colab Notebooks/QSAR MODELLING CODES/AKT1"

# Copy bioactivity_data.csv
! cp bioactivity_data.csv "{dest_dir}"

# Copy bioactivity_preprocessed_data.csv
! cp bioactivity_preprocessed_data.csv "{dest_dir}"

# %%
# Verify the files are copied
! ls -l "/content/gdrive/MyDrive/Colab Notebooks/QSAR MODELLING CODES/AKT1"
# Out:
# total 133
# -rw------- 1 root root 122535 Mar 20 10:31 bioactivity_data.csv
# -rw------- 1 root root  13019 Mar 20 10:31 bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
